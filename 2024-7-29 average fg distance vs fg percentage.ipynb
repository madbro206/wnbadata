Michaela Onyenwere,.410,12.3
Breanna Stewart,.454,12.3
Courtney Vandersloot,.459,12.3
Damiris Dantas,.750,12.2
Lorela Cubaj,.400,12.0
Skylar Diggins-Smith,.393,11.7
Brittney Sykes,.467,11.7
Cameron Brink,.398,11.6
Alanna Smith,.477,11.6
Jade Melbourne,.425,11.6
Rickea Jackson,.450,11.5
Kierstan Bell,.500,11.5
Tiffany Mitchell,.349,11.3
Layshia Clarendon,.432,11.2
Lindsay Allen,.462,10.6
Jordan Horston,.491,10.6
Natasha Howard,.457,10.5
Napheesa Collier,.468,10.3
Emily Engstler,.435,10.3
A'ja Wilson,.522,10.1
Haley Jones,.411,10.0
Dorka Juhász,.496,9.9
DiJonai Carrington,.395,9.7
Tina Charles,.452,9.6
Marquesha Davis,.417,9.6
Maddy Siegrist,.523,9.5
Nneka Ogwumike,.524,9.3
Queen Egbo,.167,9.2
Myisha Hines-Allen,.503,9.1
Isabelle Harrison,.405,9.0
Victaria Saxton,.250,9.0
DiDi Richards,.408,8.8
Chennedy Carter,.518,8.6
NaLyssa Smith,.492,8.4
Cheyenne Parker,.446,8.2
Brittney Griner,.558,8.0
Dearica Hamby,.520,7.8
Li Yueru,.493,7.8
Monique Billings,.475,7.8
Ezi Magbegor,.506,7.7
Celeste Taylor,.400,7.7
Mercedes Russell,.576,7.0
Shakira Austin,.394,6.9
Brionna Jones,.530,6.8
Temi Fagbenle,.544,6.7
Naz Hillmon,.613,6.6
Kalani Brown,.585,6.6
Aaliyah Edwards,.490,6.6
Jakia Brown-Turner,.000,6.5
Aliyah Boston,.532,6.2
Elizabeth Williams,.487,6.1
Brianna Turner,.625,6.0
Liz Dixon,.379,6.0
Natasha Mack,.558,5.6
Alyssa Thomas,.520,5.2
Angel Reese,.402,5.1
Sika Koné,.412,5.1
Teaira McCowan,.565,5.0
Charisma Osborne,.500,4.9
Olivia Nelson-Ododa,.500,4.2
Nyara Sabally,.600,3.9
Kamilla Cardoso,.462,3.3
Olivia Époupa,.400,3.1
Laeticia Amihere,.238,3.0
Dulcy Fankam Mendjiadeu,.667,2.2
Taylor Soule,,0.0
Jaylyn Sherrod,,0.0
"""

# Use StringIO to read the data from the string
df2 = pd.read_csv(StringIO(data2))

# Display the dataframe
print(df2)
# Out:
#                       Player    FG%  Dist.
# 0                  Nika Mühl  0.000   23.7
# 1              Rachel Banham  0.358   22.8
# 2              Sami Whitcomb  0.351   22.1
# 3           Kysre Gondrezick  0.286   21.2
# 4               Julie Vanloo  0.352   20.7
# ..                       ...    ...    ...
# 146            Olivia Époupa  0.400    3.1
# 147         Laeticia Amihere  0.238    3.0
# 148  Dulcy Fankam Mendjiadeu  0.667    2.2
# 149             Taylor Soule    NaN    0.0
# 150           Jaylyn Sherrod    NaN    0.0
#
# [151 rows x 3 columns]

# %%
# Calculate the correlation between Dist. and FG%
correlation = df2['Dist.'].corr(df2['FG%'])
print(f"Correlation between Dist. and FG%: {correlation}")
# Out:
# Correlation between Dist. and FG%: -0.4188267748380021

# %%
from scipy.stats import pearsonr

# Check for NaN or infinite values
if df2[['Dist.', 'FG%']].isnull().values.any() or not np.all(np.isfinite(df2[['Dist.', 'FG%']])):
    print("Data contains NaN or infinite values. Handling them...")
    df2 = df2.dropna()  # Drop rows with NaN values
    df2 = df2[np.isfinite(df2['Dist.']) & np.isfinite(df2['FG%'])]  # Remove infinite values

# Calculate the correlation coefficient and p-value
corr_coefficient, p_value = pearsonr(df2['Dist.'], df2['FG%'])

print(f"Correlation coeff between avg dist and FG%: {corr_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Correlation coeff between avg dist and FG%: -0.41882677483800224
# P-value: 1.0617145913466015e-07

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a scatter plot with a trend line
sns.lmplot(x='Dist.', y='FG%', data=df2, ci=None, scatter_kws={'s': 30, 'color': '#74618F'}, line_kws={'color': '#F88158'})
plt.title('Scatter Plot of Player Avg FGA Distance vs FG%, with Trend Line')
plt.xlabel('Distance (ft)')
plt.ylabel('Field Goal Percentage (FG%)')
plt.suptitle('2024 WNBA Season, via Basketball Reference', y=0.98, fontsize=10)
plt
# Out:
# <module 'matplotlib.pyplot' from '/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
# Set background color
bg_color = '#FCEECB'

# Create a scatter plot with a trend line
g = sns.lmplot(x='Dist.', y='FG%', data=df2, ci=None, scatter_kws={'s': 30, 'color': '#74618F'}, line_kws={'color': '#F88158'})
g.fig.set_facecolor(bg_color)
g.ax.set_facecolor(bg_color)
plt.title('Scatter Plot of Player Avg FGA Distance vs FG%, with Trend Line')
plt.xlabel('average distance from basket (ft)')
plt.ylabel('player field goal percentage (FG%)')
plt.suptitle('2024 WNBA Season, via Basketball Reference', y=0.98, fontsize=10)

plt.show()

# %%
# Create a scatter plot with a trend line
sns.lmplot(x='Dist.', y='FG%', data=df2, ci=None, scatter_kws={'s': 50}, line_kws={'color': 'red'})
plt.title('Scatter Plot of Player Avg FGA Distance vs FG%, with Trend Line')
plt.xlabel('Distance (ft)')
plt.ylabel('Field Goal Percentage (FG%)')

# Annotate points with player names
for i, row in df2.iterrows():
    plt.text(row['Dist.'], row['FG%'], row['Player'], fontsize=9, ha='right')

plt
# Out:
# <module 'matplotlib.pyplot' from '/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
import statsmodels.api as sm
# Prepare the data for the regression model
X = df2['Dist.']
y = df2['FG%']
X = sm.add_constant(X)  # Adds a constant term to the predictor

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Get the regression coefficients
intercept, slope = model.params
print(f"Intercept: {intercept}")
print(f"Slope: {slope}")
# Out:
# Intercept: 0.5454797282962079
# Slope: -0.010133477674224074
